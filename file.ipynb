# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv("india_data.csv")

# %%
df.head()
# Out:
#    District code         State name District name  Population    Male  Female  \
# 0              4  JAMMU AND KASHMIR        Kargil      140802   77785   63017
# 1              5  JAMMU AND KASHMIR         Punch      476835  251899  224936
# 2              7  JAMMU AND KASHMIR        Kathua      616435  326109  290326
# 3             10  JAMMU AND KASHMIR      Srinagar     1236829  651124  585705
# 4             12  JAMMU AND KASHMIR       Pulwama      560440  293064  267376
#
#    Literate  Male_Literate  Female_Literate      SC  ...  \
# 0     86236          56301            29935      18  ...
# 1    261724         163333            98391     556  ...
# 2    389204         228499           160705  141224  ...
# 3    748584         431746           316838    1068  ...
# 4    293958         178326           115632     402  ...
#
#    Power_Parity_Rs_150000_330000  Power_Parity_Rs_330000_425000  \
# 0                             30                             19
# ...

# %%
df.drop(columns=["State","District"],inplace=True)

# %%
list_states=list(df["State name"].unique())

# %%
sorted(list_states)
# Out:
# ['ANDHRA PRADESH',
#  'ARUNACHAL PRADESH',
#  'ASSAM',
#  'All',
#  'BIHAR',
#  'CHANDIGARH',
#  'CHHATTISGARH',
#  'DAMAN AND DIU',
#  'GOA',
#  'GUJARAT',
#  'HARYANA',
#  'HIMACHAL PRADESH',
#  'JAMMU AND KASHMIR',
#  'JHARKHAND',
#  'KARNATAKA',
#  'KERALA',
#  'MADHYA PRADESH',
#  'MAHARASHTRA',
#  'MANIPUR',
#  'MEGHALAYA',
#  'MIZORAM',
#  'NAGALAND',
#  'NCT OF DELHI',
#  'ORISSA',
#  'PONDICHERRY',
#  'PUNJAB',
#  'RAJASTHAN',
#  'TAMIL NADU',
#  'TRIPURA',
#  'UTTAR PRADESH',
#  'UTTARAKHAND',
#  'WEST BENGAL']

# %%
list_states.insert(0,"All")

# %%
list_states
# Out:
# ['All',
#  'All',
#  'JAMMU AND KASHMIR',
#  'HIMACHAL PRADESH',
#  'PUNJAB',
#  'CHANDIGARH',
#  'UTTARAKHAND',
#  'HARYANA',
#  'NCT OF DELHI',
#  'RAJASTHAN',
#  'UTTAR PRADESH',
#  'BIHAR',
#  'ARUNACHAL PRADESH',
#  'NAGALAND',
#  'MANIPUR',
#  'MIZORAM',
#  'TRIPURA',
#  'MEGHALAYA',
#  'ASSAM',
#  'WEST BENGAL',
#  'JHARKHAND',
#  'ORISSA',
#  'CHHATTISGARH',
#  'MADHYA PRADESH',
#  'GUJARAT',
#  'DAMAN AND DIU',
#  'MAHARASHTRA',
#  'ANDHRA PRADESH',
#  'KARNATAKA',
#  'GOA',
#  'KERALA',
#  'TAMIL NADU',
#  'PONDICHERRY']

# %%
df.columns.to_list()
# Out:
# ['District code',
#  'State name',
#  'District name',
#  'Population',
#  'Male',
#  'Female',
#  'Literate',
#  'Male_Literate',
#  'Female_Literate',
#  'SC',
#  'Male_SC',
#  'Female_SC',
#  'ST',
#  'Male_ST',
#  'Female_ST',
#  'Workers',
#  'Male_Workers',
#  'Female_Workers',
#  'Main_Workers',
#  'Marginal_Workers',
#  'Non_Workers',
#  'Cultivator_Workers',
#  'Agricultural_Workers',
#  'Household_Workers',
#  'Other_Workers',
#  'Hindus',
#  'Muslims',
#  'Christians',
#  'Sikhs',
#  'Buddhists',
#  'Jains',
#  'Others_Religions',
#  'Religion_Not_Stated',
#  'LPG_or_PNG_Households',
#  'Housholds_with_Electric_Lighting',
#  'Households_with_Internet',
#  'Households_with_Computer',
#  'Rural_Households',
#  'Urban_Households',
#  'Households',
#  'Below_Primary_Education',
#  'Primary_Education',
#  'Middle_Education',
#  'Secondary_Education',
#  'Higher_Education',
#  'Graduate_Education',
#  'Other_Education',
#  'Literate_Education',
#  'Illiterate_Education',
# ...

# %%
df.iloc[:,1:6].groupby("State name")["Population"].sum()
# Out:
# State name
# ANDHRA PRADESH        69147421
# ARUNACHAL PRADESH      1354556
# ASSAM                 23415900
# BIHAR                104312298
# CHANDIGARH             1055450
# CHHATTISGARH          24301046
# DAMAN AND DIU           191173
# GOA                    1458545
# GUJARAT               60248666
# HARYANA               20555285
# HIMACHAL PRADESH       7669762
# JAMMU AND KASHMIR      5526220
# JHARKHAND             24194739
# KARNATAKA             43414126
# KERALA                32208649
# MADHYA PRADESH        66444576
# MAHARASHTRA          100651341
# MANIPUR                1881689
# MEGHALAYA              2708049
# MIZORAM                1097206
# NAGALAND               1758795
# NCT OF DELHI           1709346
# ORISSA                30219438
# PONDICHERRY             297664
# PUNJAB                24421246
# RAJASTHAN             68548437
# TAMIL NADU            56044203
# TRIPURA                3673917
# UTTAR PRADESH        177691218
# ...

# %%
df[['Power_Parity_Less_than_Rs_45000','Power_Parity_Rs_45000_90000','Power_Parity_Rs_90000_150000','Power_Parity_Rs_45000_150000','Power_Parity_Rs_150000_240000','Power_Parity_Rs_240000_330000','Power_Parity_Rs_150000_330000','Power_Parity_Rs_330000_425000','Power_Parity_Rs_425000_545000','Power_Parity_Rs_330000_545000','Power_Parity_Above_Rs_545000','Total_Power_Parity',]]
# Out:
#      Power_Parity_Less_than_Rs_45000  Power_Parity_Rs_45000_90000  \
# 0                                 39                           87
# 1                                117                          268
# 2                                139                          340
# 3                                251                          427
# 4                                213                          430
# ..                               ...                          ...
# 512                              380                          969
# 513                              725                         2868
# 514                              510                         1993
# 515                              510                         1993
# 516                              407                         1345
#
#      Power_Parity_Rs_90000_150000  Power_Parity_Rs_45000_150000  \
# 0                              27                           114
# ...

# %%
(df["Power_Parity_Less_than_Rs_45000"]/df["Total_Power_Parity"])*100
# Out:
# 0      18.224299
# 1      18.600954
# 2      14.850427
# 3       8.099387
# 4      19.943820
#          ...
# 512    16.074450
# 513     5.201607
# 514     5.086267
# 515     5.086267
# 516     8.323108
# Length: 517, dtype: float64

# %%
df.head()
# Out:
#    District code         State name District name  Population    Male  Female  \
# 0              4  JAMMU AND KASHMIR        Kargil      140802   77785   63017
# 1              5  JAMMU AND KASHMIR         Punch      476835  251899  224936
# 2              7  JAMMU AND KASHMIR        Kathua      616435  326109  290326
# 3             10  JAMMU AND KASHMIR      Srinagar     1236829  651124  585705
# 4             12  JAMMU AND KASHMIR       Pulwama      560440  293064  267376
#
#    Literate  Male_Literate  Female_Literate      SC  ...  \
# 0     86236          56301            29935      18  ...
# 1    261724         163333            98391     556  ...
# 2    389204         228499           160705  141224  ...
# 3    748584         431746           316838    1068  ...
# 4    293958         178326           115632     402  ...
#
#    Power_Parity_Rs_150000_240000  Power_Parity_Rs_240000_330000  \
# 0                             12                             18
# ...

# %%
temp=df.groupby("District name")["Population"].sum().reset_index()

# %%
temp.merge(df,on=["District name","Population"])
# Out:
#     District name  Population  District code      State name     Male  \
# 0        Adilabad     2741239            532  ANDHRA PRADESH  1369597
# 1            Agra     4418797            146   UTTAR PRADESH  2364953
# 2       Ahmadabad     7214225            474         GUJARAT  3788051
# 3          Aizawl      400309            283         MIZORAM   199270
# 4           Ajmer     2583052            119       RAJASTHAN  1324085
# ..            ...         ...            ...             ...      ...
# 490  West Tripura     1725739            289         TRIPURA   879428
# 491         Wokha      166343            264        NAGALAND    84505
# 492         Yanam       55626            634     PONDICHERRY    27301
# 493      Yavatmal     2772348            510     MAHARASHTRA  1419965
# 494     Zunheboto      140757            263        NAGALAND    71217
#
#       Female  Literate  Male_Literate  Female_Literate      SC  ...  \
# ...

# %%
data=temp.merge(df,on="District name")[["District name","Population_x","District code","Latitude","Longitude"]]

# %%
df.head()
# Out:
#    District code         State name District name  Population    Male  Female  \
# 0              4  JAMMU AND KASHMIR        Kargil      140802   77785   63017
# 1              5  JAMMU AND KASHMIR         Punch      476835  251899  224936
# 2              7  JAMMU AND KASHMIR        Kathua      616435  326109  290326
# 3             10  JAMMU AND KASHMIR      Srinagar     1236829  651124  585705
# 4             12  JAMMU AND KASHMIR       Pulwama      560440  293064  267376
#
#    Literate  Male_Literate  Female_Literate      SC  ...  \
# 0     86236          56301            29935      18  ...
# 1    261724         163333            98391     556  ...
# 2    389204         228499           160705  141224  ...
# 3    748584         431746           316838    1068  ...
# 4    293958         178326           115632     402  ...
#
#    Power_Parity_Rs_150000_240000  Power_Parity_Rs_240000_330000  \
# 0                             12                             18
# ...

# %%
df["State name"].unique()
# Out:
# array(['JAMMU AND KASHMIR', 'HIMACHAL PRADESH', 'PUNJAB', 'CHANDIGARH',
#        'UTTARAKHAND', 'HARYANA', 'NCT OF DELHI', 'RAJASTHAN',
#        'UTTAR PRADESH', 'BIHAR', 'ARUNACHAL PRADESH', 'NAGALAND',
#        'MANIPUR', 'MIZORAM', 'TRIPURA', 'MEGHALAYA', 'ASSAM',
#        'WEST BENGAL', 'JHARKHAND', 'ORISSA', 'CHHATTISGARH',
#        'MADHYA PRADESH', 'GUJARAT', 'DAMAN AND DIU', 'MAHARASHTRA',
#        'ANDHRA PRADESH', 'KARNATAKA', 'GOA', 'KERALA', 'TAMIL NADU',
#        'PONDICHERRY'], dtype=object)

# %%
df[df["State name"]=="CHANDIGARH"]
# Out:
#     District code  State name District name  Population    Male  Female  \
# 37             55  CHANDIGARH    Chandigarh     1055450  580663  474787
#
#     Literate  Male_Literate  Female_Literate      SC  ...  \
# 37    805438         465346           340092  199086  ...
#
#     Power_Parity_Rs_150000_240000  Power_Parity_Rs_240000_330000  \
# 37                           4285                           2444
#
#     Power_Parity_Rs_150000_330000  Power_Parity_Rs_330000_425000  \
# 37                           6729                           3382
#
#     Power_Parity_Rs_425000_545000  Power_Parity_Rs_330000_545000  \
# 37                           4461                           7843
#
#     Power_Parity_Above_Rs_545000  Total_Power_Parity  Latitude  Longitude
# 37                          7897               34145   30.7426  76.758725
#
# [1 rows x 120 columns]

# %%
data=df[df["State name"]=="RAJASTHAN"]

# %%
data.sort_values(by="Population",ascending=False).head()
# Out:
#     District code State name District name  Population     Male   Female  \
# 75            110  RAJASTHAN        Jaipur     6626178  3468507  3157671
# 78            113  RAJASTHAN       Jodhpur     3687165  1923928  1763237
# 69            104  RAJASTHAN         Alwar     3674179  1939026  1735153
# 77            112  RAJASTHAN        Nagaur     3307743  1696325  1611418
# 95            130  RAJASTHAN       Udaipur     3068420  1566801  1501619
#
#     Literate  Male_Literate  Female_Literate       SC  ...  \
# 75   4300965        2554793          1746172  1003302  ...
# 78   2031532        1265753           765779   608024  ...
# 69   2182476        1359829           822647   653036  ...
# 77   1758624        1102750           655874   699911  ...
# 95   1582629         973444           609185   188525  ...
#
#     Power_Parity_Rs_150000_240000  Power_Parity_Rs_240000_330000  \
# 75                           1130                            645
# ...

# %%
data=df.groupby("District name")["Population"].sum().reset_index()
data=data.merge(df,on=["District name","Population"])[["District name","Population","District code","Latitude","Longitude"]]

# %%
data.sort_values(by="Population",ascending=False).head()
# Out:
#     District name  Population  District code   Latitude  Longitude
# 444         Thane    11060148            517  19.698768  72.798827
# 363          Pune     9429408            521  18.516962  74.129229
# 40     Barddhaman     7717563            335  23.444454  87.815058
# 2       Ahmadabad     7214225            474  22.605426  72.238981
# 314   Murshidabad     7103807            333  24.259507  88.168169

# %%
import plotly.express as px

# %%
df
# Out:
#      District code         State name District name  Population     Male  \
# 0                4  JAMMU AND KASHMIR        Kargil      140802    77785
# 1                5  JAMMU AND KASHMIR         Punch      476835   251899
# 2                7  JAMMU AND KASHMIR        Kathua      616435   326109
# 3               10  JAMMU AND KASHMIR      Srinagar     1236829   651124
# 4               12  JAMMU AND KASHMIR       Pulwama      560440   293064
# ..             ...                ...           ...         ...      ...
# 512            630         TAMIL NADU    Dharmapuri     1506843   774303
# 513            632         TAMIL NADU    Coimbatore     3458045  1729297
# 514            634        PONDICHERRY         Yanam       55626    27301
# 515            636        PONDICHERRY          Mahe       41816    19143
# 516            637        PONDICHERRY      Karaikal      200222    97809
#
#       Female  Literate  Male_Literate  Female_Literate      SC  ...  \
# ...

# %%
df.pivot(index="State name",columns="District name",values="Population")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 df.pivot(index="State name",columns="District name",values="Population")
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:9346, in DataFrame.pivot(self, columns, index, values)
#    9339 @Substitution("")
#    9340 @Appender(_shared_docs["pivot"])
#    9341 def pivot(
#    9342     self, *, columns, index=lib.no_default, values=lib.no_default
#    9343 ) -> DataFrame:
#    9344     from pandas.core.reshape.pivot import pivot
# -> 9346     return pivot(self, index=index, columns=columns, values=values)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\reshape\pivot.py:570, in pivot(data, columns, index, values)
#     566         indexed = data._constructor_sliced(data[values]._values, index=multiindex)
# ...

# %%
temp=df.groupby(["State name","District name"])["Population"].sum().reset_index()

# %%
temp.head()
# Out:
#        State name  District name  Population
# 0  ANDHRA PRADESH       Adilabad     2741239
# 1  ANDHRA PRADESH      Anantapur     4081148
# 2  ANDHRA PRADESH       Chittoor     4174064
# 3  ANDHRA PRADESH  East Godavari     5154296
# 4  ANDHRA PRADESH         Guntur     4887813

# %%
px.treemap(temp,path=["State name","District name"],values="Population")

# %%
data.plot(kind="pie")
# Out:
# <Axes: ylabel='Non_Workers'>

# %%
import plotly.graph_objects as go

# %%
temp
# Out:
#          State name   District name  Population
# 0    ANDHRA PRADESH        Adilabad     2741239
# 1    ANDHRA PRADESH       Anantapur     4081148
# 2    ANDHRA PRADESH        Chittoor     4174064
# 3    ANDHRA PRADESH   East Godavari     5154296
# 4    ANDHRA PRADESH          Guntur     4887813
# ..              ...             ...         ...
# 503     WEST BENGAL          Maldah     3988845
# 504     WEST BENGAL     Murshidabad     7103807
# 505     WEST BENGAL           Nadia     5167600
# 506     WEST BENGAL        Puruliya     2930115
# 507     WEST BENGAL  Uttar Dinajpur     3007134
#
# [508 rows x 3 columns]

# %%
fig = go.Figure(go.Sunburst(
        labels=temp["District name"],
        parents=temp["State name"],
        values=temp["Population"]
    ))

fig.update_layout(
        autosize=False, # Set to False to manually control width and height
        width=800,      # Increase width
        height=800      # Increase height
    )

fig.show()

# %%
temp.groupby("State name")["Population"].sum().reset_index()
# Out:
#            State name  Population
# 0      ANDHRA PRADESH    69147421
# 1   ARUNACHAL PRADESH     1354556
# 2               ASSAM    23415900
# 3               BIHAR   104312298
# 4          CHANDIGARH     1055450
# 5        CHHATTISGARH    24301046
# 6       DAMAN AND DIU      191173
# 7                 GOA     1458545
# 8             GUJARAT    60248666
# 9             HARYANA    20555285
# 10   HIMACHAL PRADESH     7669762
# 11  JAMMU AND KASHMIR     5526220
# 12          JHARKHAND    24194739
# 13          KARNATAKA    43414126
# 14             KERALA    32208649
# 15     MADHYA PRADESH    66444576
# 16        MAHARASHTRA   100651341
# 17            MANIPUR     1881689
# 18          MEGHALAYA     2708049
# 19            MIZORAM     1097206
# 20           NAGALAND     1758795
# 21       NCT OF DELHI     1709346
# 22             ORISSA    30219438
# 23        PONDICHERRY      297664
# 24             PUNJAB    24421246
# 25          RAJASTHAN    68548437
# ...

# %%
temp
# Out:
#          State name   District name  Population
# 0    ANDHRA PRADESH        Adilabad     2741239
# 1    ANDHRA PRADESH       Anantapur     4081148
# 2    ANDHRA PRADESH        Chittoor     4174064
# 3    ANDHRA PRADESH   East Godavari     5154296
# 4    ANDHRA PRADESH          Guntur     4887813
# ..              ...             ...         ...
# 503     WEST BENGAL          Maldah     3988845
# 504     WEST BENGAL     Murshidabad     7103807
# 505     WEST BENGAL           Nadia     5167600
# 506     WEST BENGAL        Puruliya     2930115
# 507     WEST BENGAL  Uttar Dinajpur     3007134
#
# [508 rows x 3 columns]

# %%
import plotly.graph_objects as go
import pandas as pd

# State-level data
state_level = temp.groupby("State name", as_index=False)[sub_category].sum()
state_level["parent"] = ""   # states have no parent

# District-level data
district_level = temp.rename(columns={"District name": "label", "State name": "parent"})
district_level = district_level[["label", "parent", sub_category]]

# Rename state-level columns
state_level = state_level.rename(columns={"State name": "label", sub_category: sub_category})

# Combine states + districts
all_nodes = pd.concat([state_level[["label","parent",sub_category]],
                       district_level[["label","parent",sub_category]]])

# Sunburst chart
fig = go.Figure(go.Sunburst(
    labels=all_nodes["label"],
    parents=all_nodes["parent"],
    values=all_nodes[sub_category]
))

fig.update_layout(
    autosize=False,
    width=800,
    height=800
)

fig.show()

# %%
import pandas as pd

# %%
df=pd.read_csv("india_data.csv")

# %%
df.head()
# Out:
#    District code         State name District name  Population    Male  Female  \
# 0              4  JAMMU AND KASHMIR        Kargil      140802   77785   63017
# 1              5  JAMMU AND KASHMIR         Punch      476835  251899  224936
# 2              7  JAMMU AND KASHMIR        Kathua      616435  326109  290326
# 3             10  JAMMU AND KASHMIR      Srinagar     1236829  651124  585705
# 4             12  JAMMU AND KASHMIR       Pulwama      560440  293064  267376
#
#    Literate  Male_Literate  Female_Literate      SC  ...  \
# 0     86236          56301            29935      18  ...
# 1    261724         163333            98391     556  ...
# 2    389204         228499           160705  141224  ...
# 3    748584         431746           316838    1068  ...
# 4    293958         178326           115632     402  ...
#
#    Power_Parity_Rs_150000_330000  Power_Parity_Rs_330000_425000  \
# 0                             30                             19
# ...

# %%
data=df[df["State name"]=="JAMMU AND KASHMIR"][["District code","District name","State name","Population",]]
data
# Out:
#    District code District name         State name  Population
# 0              4        Kargil  JAMMU AND KASHMIR      140802
# 1              5         Punch  JAMMU AND KASHMIR      476835
# 2              7        Kathua  JAMMU AND KASHMIR      616435
# 3             10      Srinagar  JAMMU AND KASHMIR     1236829
# 4             12       Pulwama  JAMMU AND KASHMIR      560440
# 5             16          Doda  JAMMU AND KASHMIR      409936
# 6             19      Udhampur  JAMMU AND KASHMIR      554985
# 7             21         Jammu  JAMMU AND KASHMIR     1529958

# %%
px.sunburst(data,path=["State name","District name"],values="Population",color_discrete_map="vividis")

# %%
data.sort_values(by="Population",ascending=False).head(1)
# Out:
#    District code District name         State name  Population
# 7             21         Jammu  JAMMU AND KASHMIR     1529958

# %%
data.sort_values(by="Population").head(1)
# Out:
#    District code District name         State name  Population
# 0              4        Kargil  JAMMU AND KASHMIR      140802

# %%
import plotly.express as px

# %%
df=pd.read_csv("india_data.csv")

# %%
df.columns.to_list()
# Out:
# ['District code',
#  'State name',
#  'District name',
#  'Population',
#  'Male',
#  'Female',
#  'Literate',
#  'Male_Literate',
#  'Female_Literate',
#  'SC',
#  'Male_SC',
#  'Female_SC',
#  'ST',
#  'Male_ST',
#  'Female_ST',
#  'Workers',
#  'Male_Workers',
#  'Female_Workers',
#  'Main_Workers',
#  'Marginal_Workers',
#  'Non_Workers',
#  'Cultivator_Workers',
#  'Agricultural_Workers',
#  'Household_Workers',
#  'Other_Workers',
#  'Hindus',
#  'Muslims',
#  'Christians',
#  'Sikhs',
#  'Buddhists',
#  'Jains',
#  'Others_Religions',
#  'Religion_Not_Stated',
#  'LPG_or_PNG_Households',
#  'Housholds_with_Electric_Lighting',
#  'Households_with_Internet',
#  'Households_with_Computer',
#  'Rural_Households',
#  'Urban_Households',
#  'Households',
#  'Below_Primary_Education',
#  'Primary_Education',
#  'Middle_Education',
#  'Secondary_Education',
#  'Higher_Education',
#  'Graduate_Education',
#  'Other_Education',
#  'Literate_Education',
#  'Illiterate_Education',
# ...

# %%
df["State name"].unique()
# Out:
# array(['JAMMU AND KASHMIR', 'HIMACHAL PRADESH', 'PUNJAB', 'CHANDIGARH',
#        'UTTARAKHAND', 'HARYANA', 'NCT OF DELHI', 'RAJASTHAN',
#        'UTTAR PRADESH', 'BIHAR', 'ARUNACHAL PRADESH', 'NAGALAND',
#        'MANIPUR', 'MIZORAM', 'TRIPURA', 'MEGHALAYA', 'ASSAM',
#        'WEST BENGAL', 'JHARKHAND', 'ORISSA', 'CHHATTISGARH',
#        'MADHYA PRADESH', 'GUJARAT', 'DAMAN AND DIU', 'MAHARASHTRA',
#        'ANDHRA PRADESH', 'KARNATAKA', 'GOA', 'KERALA', 'TAMIL NADU',
#        'PONDICHERRY'], dtype=object)

# %%
data[["District code","State name","District name",sub_category]]

# %%
df[df["State name"]=="UTTARAKHAND"]
# Out:
#     District code   State name      District name  Population    Male  Female  \
# 38             56  UTTARAKHAND         Uttarkashi      330086  168597  161489
# 39             57  UTTARAKHAND            Chamoli      391605  193991  197614
# 40             59  UTTARAKHAND      Tehri Garhwal      618931  297986  320945
# 41             62  UTTARAKHAND        Pithoragarh      483439  239306  244133
# 42             63  UTTARAKHAND          Bageshwar      259898  124326  135572
# 43             64  UTTARAKHAND             Almora      622506  291081  331425
# 44             65  UTTARAKHAND          Champawat      259648  131125  128523
# 45             67  UTTARAKHAND  Udham Singh Nagar     1648902  858783  790119
#
#     Literate  Male_Literate  Female_Literate      SC  ...  \
# 38    215126         128237            86889   80567  ...
# 39    280556         155395           125161   79317  ...
# 40    407994         227406           180588  102130  ...
# ...

# %%
data=df.groupby("District name")["Male_Literate"].sum().reset_index()

# %%
data.merge(df,on=["District name","Male_Literate"])[["State name","District name","Male_Literate","District code","Latitude","Longitude"]]
# Out:
#          State name District name  Male_Literate  District code   Latitude  \
# 0    ANDHRA PRADESH      Adilabad         856350            532  19.284514
# 1     UTTAR PRADESH          Agra        1614594            146  26.995130
# 2           GUJARAT     Ahmadabad        3025463            474  22.605426
# 3           MIZORAM        Aizawl         169547            283  23.907813
# 4         RAJASTHAN         Ajmer         926268            119  26.199300
# ..              ...           ...            ...            ...        ...
# 490         TRIPURA  West Tripura         722998            289  23.780166
# 491        NAGALAND         Wokha          67385            264  26.202612
# 492     PONDICHERRY         Yanam          19919            634  16.707696
# 493     MAHARASHTRA      Yavatmal        1115980            510  20.042583
# 494        NAGALAND     Zunheboto          53504            263  26.028178
#
#      Longitude
# 0    78.813212
# 1    78.052783
# 2    72.238981
# ...

# %%
df.groupby(["State name", "District name", "District code", "Latitude", "Longitude"])["Male_Literate"].sum().reset_index()
# Out:
#          State name   District name  District code   Latitude  Longitude  \
# 0    ANDHRA PRADESH        Adilabad            532  19.284514  78.813212
# 1    ANDHRA PRADESH       Anantapur            553  14.312066  77.460158
# 2    ANDHRA PRADESH        Chittoor            554  13.331093  78.927639
# 3    ANDHRA PRADESH   East Godavari            545  16.782718  82.243207
# 4    ANDHRA PRADESH          Guntur            548  15.884926  80.586576
# ..              ...             ...            ...        ...        ...
# 512     WEST BENGAL          Maldah            332  25.080268  88.171917
# 513     WEST BENGAL     Murshidabad            333  24.259507  88.168169
# 514     WEST BENGAL           Nadia            336  23.564110  88.582930
# 515     WEST BENGAL        Puruliya            340  23.254192  86.396853
# 516     WEST BENGAL  Uttar Dinajpur            330  26.044619  88.235952
#
#      Male_Literate
# 0           856350
# 1          1338474
# 2          1484794
# ...

# %%
df.groupby(["State name","District name"])["Male_Literate"].sum().reset_index().sort_values(by=["Male_Literate"],ascending=False).drop_duplicates(subset=["State name"],ignore_index=True)
# Out:
#            State name      District name  Male_Literate
# 0         MAHARASHTRA              Thane        4591396
# 1             GUJARAT          Ahmadabad        3025463
# 2         WEST BENGAL         Barddhaman        2918040
# 3           RAJASTHAN             Jaipur        2554793
# 4       UTTAR PRADESH          Allahabad        2199340
# 5               BIHAR              Patna        2028047
# 6          TAMIL NADU            Chennai        1968079
# 7        CHHATTISGARH           Bilaspur        1864948
# 8           KARNATAKA            Belgaum        1725548
# 9      ANDHRA PRADESH      East Godavari        1716933
# 10             KERALA         Malappuram        1597404
# 11             PUNJAB           Ludhiana        1428348
# 12     MADHYA PRADESH             Indore        1289631
# 13             ORISSA             Ganjam        1262652
# 14          JHARKHAND             Ranchi        1085244
# 15              ASSAM             Nagaon         921850
# ...

# %%
data=df[df["State name"]=="ARUNACHAL PRADESH"][["District code","District name","State name","Population",]]

# %%
data.head()
# Out:
#      District code    District name         State name  Population
# 197            245           Tawang  ARUNACHAL PRADESH       49977
# 198            246      West Kameng  ARUNACHAL PRADESH       83947
# 199            247      East Kameng  ARUNACHAL PRADESH       78690
# 200            248       Papum Pare  ARUNACHAL PRADESH      176573
# 201            249  Upper Subansiri  ARUNACHAL PRADESH       83448

# %%
data=data.sort_values(by="Population",ascending=False,ignore_index=True)[["District name","Population"]]
data.index+=1

# %%
data
# Out:
#           District name  Population
# 1            Papum Pare      176573
# 2             Changlang      148226
# 3                 Lohit      145726
# 4            West Siang      112274
# 5                 Tirap      111975
# 6            East Siang       99214
# 7          Kurung Kumey       92076
# 8           West Kameng       83947
# 9       Upper Subansiri       83448
# 10      Lower Subansiri       83030
# 11          East Kameng       78690
# 12  Lower Dibang Valley       54080
# 13               Tawang       49977
# 14          Upper Siang       35320
